# %%
import pymysql

# %%
connection = pymysql.connect(
    host='localhost',
    user='root',
    password='Abdec@90',
    database='market',
    cursorclass=pymysql.cursors.DictCursor
)

# %%
try:
    with connection.cursor() as cursor:
        # Example query
        sql = "SELECT * FROM Country;"
        #sql = "DESCRIBE Country;"
        cursor.execute(sql)
        results = cursor.fetchall()
        for row in results:
            print((row))
finally:
    pass
    #connection.close()

# %%
import requests
from datetime import datetime

headers = {
    "User-Agent": "Mozilla/5.0"
}
url = "https://www.nseindia.com/api/search/autocomplete?q=VEDL"
response = requests.get(url, headers=headers)

a = response.json()
b = a['symbols'][0]['listing_date']
ListingDate = datetime.strptime(b, "%Y-%m-%d").date()

ISIN = 'INE205A01025'

values = (ListingDate, ISIN)

# %%
try:
    with connection.cursor() as cursor:
        # Example query
        sql = "Update stock set ListingDate = %s where ISIN = %s"
        cursor.execute(sql, values)
        connection.commit()
        results = cursor.rowcount
        print(results)
finally:
    pass
    #connection.close()
# Out:
# 0

# %%
import requests
from datetime import datetime

# %%
def get_listing_date(ISIN, symbol):
    

    headers = {
        "User-Agent": "Mozilla/5.0"
    }
    url = f"https://www.nseindia.com/api/search/autocomplete?q={symbol}"
    response = requests.get(url, headers=headers)

    a = response.json()
    b = a['symbols'][0]['listing_date']
    ListingDate = datetime.strptime(b, "%Y-%m-%d").date()

    values = (ListingDate, ISIN)
    return values

# %%
from mymodule.DatabaseConnection import CRUD

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ['database']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 os.environ['database']
#
# NameError: name 'os' is not defined

# %%
lo_stock = CRUD('Stock')
# Out:
# market

# %%
df_stock = lo_stock.Read('')

# %%
lo_sestockcode = CRUD('stockexchange_stockcode')
# Out:
# market

# %%
df_sestockcode = lo_sestockcode.Read('')

# %%
try:
    with connection.cursor() as cursor:
        # Example query
        sql = "Update stock set ListingDate = %s where ISIN = %s"
        cursor.execute(sql, values)
        connection.commit()
        results = cursor.rowcount
        print(results)
finally:
    pass
    #connection.close()

# %%
try:
    with connection.cursor() as cursor:
        # Example query
        sql = "Update stock set ListingDate = %s where ISIN = %s"
        for i, row in df_sestockcode.iterrows():
            if row['StockExchange'] == 'NSE':
                values = get_listing_date(row['ISIN'], row['Symbol'])
                cursor.execute(sql, values)
                connection.commit()
finally:
    pass
# Out:
# 2011-11-30
# 2009-02-13
# 2002-01-21
# 1995-11-29
# 2010-05-20
# 2016-07-01
# 1995-09-06
# 2025-02-06
# 2024-07-31
# 2007-03-19
# 2007-03-20
# 2021-03-22
# 1995-06-28
# 2005-07-01
# 2023-11-30
# 1995-09-20
# 2018-02-05
# 1995-02-08
# 2018-12-28
# 2023-04-21
# 2022-11-16
# 2022-02-16
# 2022-04-13
# 2022-05-20
# 2021-09-14
# 2024-11-13
# 2018-06-20
# 2021-02-05
# 2021-02-16
# 2022-04-07
# 2021-03-25
# 2019-08-20
# 2024-08-26
# 2022-12-08
# 2021-01-28
# 2021-07-28
# 2019-01-22
# 2025-08-12
# 2018-12-28
# 2024-08-13
# 2022-07-01
# 2019-08-08
# 2023-12-01
# 2021-02-16
# 2024-11-08
# 2022-05-04
# 2022-12-23
# 2024-02-16
# 2003-08-20
# 2000-04-18
# 2017-06-27
# 2016-09-23
# 2024-04-29
# 2021-12-13
# 1996-11-20
# 2022-07-27
# 2025-01-24
# 1995-12-06
# 2025-04-17
# 2008-01-08
# 1999-04-28
# 2017-12-11
# 2006-11-27
# 2021-11-25
# 2021-03-31
# 2004-06-23
# 2020-03-16
# 2005-03-23
# 2007-03-02
# 2010-10-05
# 2024-06-28
# 2021-01-01
# 2023-07-10
# 2024-12-18
# 2022-11-23
# 2022-04-12
# 2025-03-28
# 2024-09-06
# 2021-02-22
# 2018-10-10
# 2023-01-06
# 2020-12-02
# 2022-11-28
# 2024-10-09
# 2019-02-04
# 2022-06-01
# 2019-01-25
# 2008-03-12
# 2023-01-20
# 2006-10-30
# 2008-06-04
# 1995-05-31
# 2021-06-28
# 1996-01-31
# 2007-08-23
# 2017-10-23
# 2003-11-17
# 2005-07-18
# 2011-10-04
# 2023-08-31
# 1995-05-10
# 2010-11-16
# 2005-03-29
# 2005-08-29
# 2020-01-23
# 1995-09-06
# 1998-01-07
# 2020-08-21
# 1997-02-19
# 1995-09-13
# 2011-01-14
# 2020-07-23
# 2021-06-04
# 2022-06-21
# 2024-01-31
# 2024-09-05
# 2023-12-28
# 2024-06-07
# 2021-11-12
# 2020-07-22
# 2024-08-13
# 2022-01-17
# 2022-10-17
# 1995-07-06
# 2017-05-19
# 2000-05-29
# 1995-04-26
# 2005-06-17
# 2020-10-28
# 1995-02-08
# 2007-01-29
# 2015-08-26
# 2023-01-12
# 1995-06-28
# 1995-02-08
# 2000-10-11
# 2000-07-26
# 2004-01-23
# 2024-12-27
# 1997-01-08
# 2004-01-16
# 1995-04-26
# 2000-05-02
# 2010-12-10
# 2019-10-30
# 2025-02-14
# 2024-06-26
# 2023-10-30
# 2023-08-14
# 2019-06-18
# 2024-05-23
# 2025-07-31
# 2021-08-06
# 2020-03-09
# 2021-03-10
# 2020-02-14
# 2020-10-01
# 1995-11-08
# 2012-09-25
# 2005-10-19
# 2011-08-26
# 1995-03-29
# 1995-03-01
# 1995-03-29
# 1995-09-13
# 2021-09-14
# 1995-02-08
# 2021-10-01
# 1995-05-10
# 2003-05-28
# 2015-01-15
# 1995-11-29
# 2023-12-26
# 1995-05-10
# 2009-12-14
# 2013-04-09
# 2000-03-01
# 2024-04-03
# 2007-06-01
# 1995-02-08
# 2000-02-23
# 2008-03-11
# 2021-11-23
# 2019-04-22
# 2019-05-16
# 2022-05-30
# 2019-06-14
# 2022-12-30
# 1996-04-03
# 1999-09-15
# 2007-04-05
# 2005-08-30
# 2012-05-17
# 2006-04-03
# 2011-08-17
# 2015-01-20
# 2024-04-10
# 1996-07-03
# 2021-01-29
# 2024-12-12
# 2005-03-02
# 2003-06-27
# 1995-03-01
# 2023-07-10
# 2009-12-03
# 2003-05-19
# 1996-07-10
# 2022-12-27
# 1995-02-08
# 2004-03-09
# 2007-03-16
# 2019-12-26
# 2023-09-11
# 2025-07-03
# 2023-02-10
# 2022-11-07
# 2020-10-15
# 1995-02-08
# 2001-02-07
# 2011-10-19
# 2022-02-15
# 1997-01-08
# 2007-05-09
# 1995-03-01
# 2006-09-29
# 2023-03-06
# 2020-11-02
# 2001-02-21
# 2022-11-21
# 2009-01-30
# 2024-05-13
# 2004-09-07
# 2018-03-28
# 2014-05-09
# 2015-04-09
# 1995-03-01
# 2010-10-12
# 2020-11-20
# 2007-03-23
# 2024-09-04
# 2019-04-05
# 2025-07-30
# 2025-08-05
# 2025-08-26
# 2025-08-01
# 1995-04-26
# 1997-11-26
# 2007-05-30
# 2006-09-27
# 2015-03-09
# 2010-08-23
# 2017-04-10
# 2021-08-18
# 1996-07-17
# 2020-02-12
# 2021-06-24
# 2024-01-23
# 1995-10-11
# 2007-01-03
# 1995-11-08
# 2023-10-12
# 1995-08-23
# 2016-03-30
# 2007-01-29
# 1996-04-03
# 2014-06-26
# 2025-08-26
# 1998-02-18
# 2022-03-22
# 2023-09-22
# 2021-03-19
# 2020-07-30
# 2021-12-28
# 2023-06-01
# 2020-12-14
# 2023-10-26
# 2020-03-30
# 1995-05-10
# 1999-10-20
# 2024-10-17
# 2025-08-25
# 1998-11-18
# 1999-06-09
# 2017-08-09
# 1999-11-24
# 2007-04-02
# 2006-12-28
# 2006-05-08
# 1997-04-30
# 2023-05-09
# 1995-06-14
# 2010-02-19
# 2003-06-20
# 1995-09-06
# 2008-05-21
# 2005-10-31
# 2020-09-29
# 2022-05-27
# 2003-05-30
# 2000-12-08
# 2023-11-06
# 2019-07-16
# 2021-08-16
# 2025-08-06
# 2024-07-26
# 2023-09-22
# 2019-10-23
# 2025-06-04
# 1997-09-17
# 2003-02-20
# 2003-12-09
# 1999-04-01
# 1997-05-07
# 2015-11-06
# 2025-02-19
# 2000-03-21
# 2010-10-20
# 2016-07-18
# 1998-06-17
# 2007-12-13
# 2020-10-12
# 1998-01-28
# 2008-01-11
# 2012-04-12
# 2002-12-19
# 2022-04-19
# 2015-01-02
# 2014-01-01
# 2018-04-04
# 2020-12-18
# 2020-07-14
# 2023-05-10
# 2019-10-16
# 2021-02-02
# 2024-08-06
# 2020-10-19
# 2022-10-19
# 2023-09-05
# 2024-08-08
# 2020-10-22
# 2023-05-12
# 2020-12-23
# 2025-06-02
# 2024-06-10
# 2022-12-05
# 2024-07-10
# 2021-11-30
# 2024-09-03
# 2023-01-24
# 2023-10-16
# 2021-12-21
# 2022-06-03
# 2025-06-03
# 2021-03-19
# 2025-06-20
# 2024-03-07
# 2020-08-28
# 2020-10-01
# 2024-11-14
# 2024-09-24
# 2021-12-17
# 2021-08-18
# 2022-03-23
# 2025-07-21
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 3
#       1 for i, row in df_sestockcode.iterrows():
#       2     if row['StockExchange'] == 'NSE':
# ----> 3         get_listing_date(row['ISIN'], row['Symbol'])
#
# Cell In[11], line 8, in get_listing_date(ISIN, symbol)
#       4 headers = {
#       5     "User-Agent": "Mozilla/5.0"
#       6 }
#       7 url = f"https://www.nseindia.com/api/search/autocomplete?q={symbol}"
# ----> 8 response = requests.get(url, headers=headers)
#      10 a = response.json()
#      11 b = a['symbols'][0]['listing_date']
#
# File c:\Projects\Market\venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Projects\Market\venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Projects\Market\venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Projects\Market\venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Projects\Market\venv\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File c:\Projects\Market\venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Projects\Market\venv\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     461 try:
#     462     # Trigger any extra validation we need to do.
#     463     try:
# --> 464         self._validate_conn(conn)
#     465     except (SocketTimeout, BaseSSLError) as e:
#     466         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Projects\Market\venv\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 # Force connect early to allow us to validate the connection.
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1096 if not conn.is_verified and not conn.proxy_is_verified:
#
# File c:\Projects\Market\venv\Lib\site-packages\urllib3\connection.py:790, in HTTPSConnection.connect(self)
#     787     # Remove trailing '.' from fqdn hostnames to allow certificate validation
#     788     server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 790     sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     791         sock=sock,
#     792         cert_reqs=self.cert_reqs,
#     793         ssl_version=self.ssl_version,
#     794         ssl_minimum_version=self.ssl_minimum_version,
#     795         ssl_maximum_version=self.ssl_maximum_version,
#     796         ca_certs=self.ca_certs,
#     797         ca_cert_dir=self.ca_cert_dir,
#     798         ca_cert_data=self.ca_cert_data,
#     799         cert_file=self.cert_file,
#     800         key_file=self.key_file,
#     801         key_password=self.key_password,
#     802         server_hostname=server_hostname_rm_dot,
#     803         ssl_context=self.ssl_context,
#     804         tls_in_tls=tls_in_tls,
#     805         assert_hostname=self.assert_hostname,
#     806         assert_fingerprint=self.assert_fingerprint,
#     807     )
#     808     self.sock = sock_and_verified.socket
#     810 # If an error occurs during connection/handshake we may need to release
#     811 # our lock so another connection can probe the origin.
#
# File c:\Projects\Market\venv\Lib\site-packages\urllib3\connection.py:969, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     966     if is_ipaddress(normalized):
#     967         server_hostname = normalized
# --> 969 ssl_sock = ssl_wrap_socket(
#     970     sock=sock,
#     971     keyfile=key_file,
#     972     certfile=cert_file,
#     973     key_password=key_password,
#     974     ca_certs=ca_certs,
#     975     ca_cert_dir=ca_cert_dir,
#     976     ca_cert_data=ca_cert_data,
#     977     server_hostname=server_hostname,
#     978     ssl_context=context,
#     979     tls_in_tls=tls_in_tls,
#     980 )
#     982 try:
#     983     if assert_fingerprint:
#
# File c:\Projects\Market\venv\Lib\site-packages\urllib3\util\ssl_.py:458, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     456 if ca_certs or ca_cert_dir or ca_cert_data:
#     457     try:
# --> 458         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     459     except OSError as e:
#     460         raise SSLError(e) from e
#
# KeyboardInterrupt:

# %%
get_listing_date('PAGEIND')
# Out:
# 2007-03-16

# %%
import pandas as pd

# %%
df_bulk = pd.read_csv('.\Data\Block Deal\BSE\Block_01Jan2000to05Oct2025.csv', dtype={'Security Code':object}, parse_dates=['Deal Date'], dayfirst=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_40268\3096419382.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df_bulk = pd.read_csv('.\Data\Block Deal\BSE\Block_01Jan2000to05Oct2025.csv', dtype={'Security Code':object}, parse_dates=['Deal Date'], dayfirst=True)

# %%
df_bulk.head()
# Out:
#     Deal Date  Security Code   Company                         Client Name  \
# 0  29-11-2005         523886  MICROINK           BILAKHIA HOLDINGS PVT LTD
# 1  29-11-2005         523886  MICROINK           MUMBAI INTEGRATED SEZ LTD
# 2  29-11-2005         507878   UNITECH  PRAKAUSLI INVESTMENT INDIA PVT LTD
# 3  29-11-2005         507878   UNITECH      UNIBUILD ENGG AND CONSTURCTION
# 4  29-11-2005         523886  MICROINK           NARENDRA DHARMSINGH DESAI
#
#   Deal Type  Quantity  Price
# 0         S   1378031  640.0
# 1         P   1172000  640.0
# 2         P    235000  650.0
# 3         S    235000  650.0
# 4         P    126031  640.0

# %%
df_bulk['Client Name'].unique()
# Out:
# array(['BILAKHIA HOLDINGS PVT LTD', 'MUMBAI INTEGRATED SEZ LTD',
#        'PRAKAUSLI INVESTMENT INDIA PVT LTD', ...,
#        'NEO INFRA INCOME OPPORTUNITIES FUND',
#        'PICO CAPITAL PRIVATE LIMITED',
#        'B ARUNKUMAR CAPITAL & CREDIT SERVICES PVT LTD'],
#       shape=(5358,), dtype=object)

# %%
df_bulk.shape
# Out:
# (21460, 7)

# %%
from mymodule.DatabaseConnection import CRUD

# %%
lo_client = CRUD('client')

# %%
df_client = lo_client.Read('')

# %%
i = 0
for name in df_bulk['Client Name'].unique():
    df_client.loc[i] = [i+1, name]
    i = i + 1
print(i)
# Out:
# 5358

# %%
df_client.shape
# Out:
# (5358, 2)

# %%
df_client[1400:1410]
# Out:
#       client_id                                             name
# 1400       1401                          SESA RESOURCES LIIMITED
# 1401       1402                                BINITABEN K PATEL
# 1402       1403                           TRUST FINSTOCK PVT LTD
# 1403       1404                                   DHRUV  SAWHNEY
# 1404       1405                                    RATI  SAWHNEY
# 1405       1406               UMANANDA TRADE AND FINANCE LIMITED
# 1406       1407                         DHANKARI INVESTMENTS LTD
# 1407       1408  BHUPATI INVESTMENTS AND FINANCE PRIVATE LIMITED
# 1408       1409                               RAHUL VINOD PODDAR
# 1409       1410                          VISHAL FURNISHINGS LTD.

# %%
rows = 5100
lo_client.Create(df_client[rows:])

# %%
df_client[rows:rows+1]
# Out:
#       client_id                                               name
# 4743       4744  INTERNATIONAL MONETARY FUND (IN RESPECT OF THE...

# %%
lo_stockcode = CRUD('stockexchange_stockcode')

# %%
df_stock = lo_stockcode.Read('')

# %%
df_stock.shape
# Out:
# (3722, 3)

# %%
df_stock[df_stock['Symbol']=='500295'] #['ISIN'][0]
# Out:
#               ISIN StockExchange  Symbol
# 1140  INE205A01025           BSE  500295

# %%
dealtype = lambda x: 'B' if x == 'P' else x

# %%
df_client[df_client['name'] == row['Client Name']['client_id'][0]]
# Out:
# 'B'

# %%
lo_blockdeal = CRUD('blockdeal')
#df_blockdeal = lo_blockdeal.Read('')
# Out:
# DataBase Disconnected

# %%
df_blockdeal.shape
# Out:
# (0, 7)

# %%
df_blockdeal.dtypes
# Out:
# ISIN             object
# DealDate         object
# StockExchange    object
# Client           object
# DealType         object
# Quantity         object
# price            object
# dtype: object

# %%
count = 0
df_blockdeal = pd.DataFrame(columns={
    'ISIN':object,
    'DealDate':"datetime64[ns]",
    'StockExchange':object,
    'Client':object,
    'DealType':object,
    'Quantity':"int64",
    'price':"float64"})
for i, row in df_bulk.iterrows():
    a = df_stock[df_stock['Symbol']==row['Security Code']]
    if a.shape[0] == 0:
        continue
    else:
        list1 = [a['ISIN'].values[0], 
                 datetime.date(row['Deal Date']), 
                 'BSE', 
                 int(df_client[df_client['name'] == row['Client Name']]['client_id'].values[0]),
                 dealtype(row['Deal Type']),
                 row['Quantity'],
                 row['Price']
                 ]
        df_blockdeal.loc[count] = list1
        count = count + 1

print(count)
# Out:
# 16343

# %%
#df_blockdeal['Client'] = df_blockdeal['Client'].astype(object)
df_blockdeal["DealDate"] = pd.to_datetime(df_blockdeal['DealDate'], format="%Y-%m-%d", errors="coerce")
df_blockdeal.dtypes
# Out:
# ISIN                     object
# DealDate         datetime64[ns]
# StockExchange            object
# Client                   object
# DealType                 object
# Quantity                  int64
# price                   float64
# DealDate1        datetime64[ns]
# dtype: object

# %%
df_blockdeal.drop(['DealDate1'], axis=1, inplace=True)

# %%
df_bulk[:20]
# Out:
#     Deal Date Security Code   Company                         Client Name  \
# 0  2005-11-29        523886  MICROINK           BILAKHIA HOLDINGS PVT LTD
# 1  2005-11-29        523886  MICROINK           MUMBAI INTEGRATED SEZ LTD
# 2  2005-11-29        507878   UNITECH  PRAKAUSLI INVESTMENT INDIA PVT LTD
# 3  2005-11-29        507878   UNITECH      UNIBUILD ENGG AND CONSTURCTION
# 4  2005-11-29        523886  MICROINK           NARENDRA DHARMSINGH DESAI
# 5  2005-11-29        507878   UNITECH      MILLENIUM CONSTURCTION PVT LTD
# 6  2005-11-29        507878   UNITECH      PRAKAUSLI INVESTMENT INDIA LTD
# 7  2005-11-29        523886  MICROINK                  KAMAL VISARIA  HUF
# 8  2005-12-05        532129  HEXAWARE                      IRVINE LIMITED
# 9  2005-12-05        532129  HEXAWARE        UBS SECURITIES ASIA LIMITED.
# 10 2005-12-05        500325  RELIANCE      EKLAVYA MERCANTILE PRIVATE LTD
# 11 2005-12-05        500325  RELIANCE          SPARK TRADECOM PRIVATE LTD
# 12 2005-12-05        500325  RELIANCE             BHUMIKA TRADING PVT LTD
# 13 2005-12-05        500325  RELIANCE        PLATINUM COMMERCIALS PVT LTD
# 14 2005-12-05        500325  RELIANCE           NEELAM MERCANTILE PVT LTD
# 15 2005-12-05        500325  RELIANCE         EKANSHA ENTERPRISES PVT LTD
# 16 2005-12-07        532129  HEXAWARE                      IRVINE LIMITED
# 17 2005-12-07        532129  HEXAWARE                  MACQUARIE BANK LTD
# 18 2005-12-08        500325  RELIANCE      EKLAVYA MERCANTILE PRIVATE LTD
# 19 2005-12-08        500325  RELIANCE          SPARK TRADECOM PRIVATE LTD
#
#    Deal Type  Quantity   Price
# 0          S   1378031  640.00
# 1          P   1172000  640.00
# 2          P    235000  650.00
# 3          S    235000  650.00
# 4          P    126031  640.00
# 5          S     93468  650.00
# 6          P     93468  650.00
# 7          P     80000  640.00
# 8          S   2500000  104.00
# 9          P   2500000  104.00
# 10         P     80063  846.65
# 11         S     80063  846.65
# 12         P     67063  847.00
# 13         S     67063  847.00
# 14         S     60063  847.55
# 15         P     60063  847.55
# 16         S   2500000  108.25
# 17         P   2500000  108.25
# 18         P   1200000  847.85
# 19         S   1200000  847.85

# %%
import uuid

# %%
df_blockdeal['UUID'] = [uuid.uuid4() for _ in range(len(df_blockdeal))]

# %%
cols = ["UUID"] + [col for col in df_blockdeal.columns if col != "UUID"]
df_blockdeal = df_blockdeal[cols]

# %%
df_blockdeal.head()
# Out:
#                                    UUID          ISIN   DealDate  \
# 0  cd4f63b7-b589-4e17-9ebd-ebb2d0169922  INE694A01020 2005-11-29
# 1  a36c146a-f1d4-4d1e-a39c-3fc192ba2b6f  INE694A01020 2005-11-29
# 2  61890f1b-b266-4037-b1ec-a1c0a1998d79  INE694A01020 2005-11-29
# 3  956eae46-13f1-4a63-9ab1-8a52471dc398  INE694A01020 2005-11-29
# 4  fdaf92fd-6e11-476e-b177-f37c9a90fb1e  INE002A01018 2005-12-05
#
#   StockExchange Client DealType  Quantity   price
# 0           BSE      3        B    235000  650.00
# 1           BSE      4        S    235000  650.00
# 2           BSE      6        S     93468  650.00
# 3           BSE      7        B     93468  650.00
# 4           BSE     11        B     80063  846.65

# %%
row = 20
lo_blockdeal.Create(df_blockdeal[row:])
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df_blockdeal[1:row+1]
# Out:
#             ISIN   DealDate StockExchange Client DealType  Quantity   price
# 1   INE694A01020 2005-11-29           BSE      4        S    235000  650.00
# 2   INE694A01020 2005-11-29           BSE      6        S     93468  650.00
# 3   INE694A01020 2005-11-29           BSE      7        B     93468  650.00
# 4   INE002A01018 2005-12-05           BSE     11        B     80063  846.65
# 5   INE002A01018 2005-12-05           BSE     12        S     80063  846.65
# 6   INE002A01018 2005-12-05           BSE     13        B     67063  847.00
# 7   INE002A01018 2005-12-05           BSE     14        S     67063  847.00
# 8   INE002A01018 2005-12-05           BSE     15        S     60063  847.55
# 9   INE002A01018 2005-12-05           BSE     16        B     60063  847.55
# 10  INE002A01018 2005-12-08           BSE     11        B   1200000  847.85
# 11  INE002A01018 2005-12-08           BSE     12        S   1200000  847.85
# 12  INE002A01018 2005-12-08           BSE     18        S    807063  844.15
# 13  INE002A01018 2005-12-08           BSE     19        B    807063  844.15
# 14  INE002A01018 2005-12-08           BSE     20        S    807002  847.45
# 15  INE002A01018 2005-12-08           BSE     11        B    807002  847.45

# %%
df_blockdeal.loc[0]['DealDate']
# Out:
# datetime.date(2005, 11, 29)

# %%
df_bulk.sample(2)
# Out:
#        Deal Date Security Code     Company  \
# 3123  21-11-2012        505533    WESTLIFE
# 9554  17-06-2020        509930  SUPREMEIND
#
#                                             Client Name Deal Type  Quantity  \
# 3123                              HORIZON IMPEX PVT LTD         P    400000
# 9554  VENKTESH INVESTMENT AND TRADING COMPANY PRIVAT...         S   1225000
#
#        Price
# 3123   152.2
# 9554  1080.0
